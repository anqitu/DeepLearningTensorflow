# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os,sys

from keras.datasets import mnist
# Out:
# Using TensorFlow backend.

# %%
(x_train,y_train),(x_test,y_test) = mnist.load_data()
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step

# %%
x_train = x_train.astype(np.int64)
x_test = x_test.astype(np.int64)

# %%
train_path = os.path.abspath('./mnist_train.tfrecords')
test_path = os.path.abspath('./mnist_test.tfrecords')

# %% [markdown]
# `Numpy int format ---> Numpy string format ---> TF Example ---> Serialized Example ---> TFRecords Format`

# %%
def _int64_feature(value):
    return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))

def _bytes_feature(value):
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))

# %%
def convert_to_records(x,y,path):
    print('writing to {}'.format(path))
    with tf.python_io.TFRecordWriter(path) as writer:
        for i in range(x.shape[0]):
            example = tf.train.Example(features = tf.train.Features(
                            feature = 
                            {
                                'image_raw':_bytes_feature(x[i].tostring()),
                                'label':_int64_feature(int(y[i]))
                            }
                                                                    )
                                      )
            writer.write(example.SerializeToString())
            if i%5000==0:
                print('writing {}th image'.format(i))

# %%
convert_to_records(x_train,y_train,train_path)
# Out:
# writing to /content/mnist_train.tfrecords
# writing 0th image
# writing 5000th image
# writing 10000th image
# writing 15000th image
# writing 20000th image
# writing 25000th image
# writing 30000th image
# writing 35000th image
# writing 40000th image
# writing 45000th image
# writing 50000th image
# writing 55000th image

# %%
convert_to_records(x_test,y_test,test_path)
# Out:
# writing to /content/mnist_test.tfrecords
# writing 0th image
# writing 5000th image
